# %%
while True:
    answer = input("Enter a movie you like or press 'q' to quit:")
    if answer.lower() == 'q':
        break
        else:
            print("You entered + answer")
            
print you("You will know exit the program")

'''
A string is a sequence of zero or more characters.

The len () function returns the number of characters in it's string argument.
Each character occupies a posititon in the string. The positions range from 0 to the length of the string minus 1.
A string is immutable. This means it does not change once it is created.

The subscipt operator [] can be used to access a character at a given position in a string.
'''
s = "This is my string"

i = 0

numberSpace = 0

print(len(s))

print(s[4])

print("Printing the subscript from 5 to 10: +s[5:10]")

for eachCharacter in range (lens(s)-1,-1,-1):
    
    print(s[eachCharater],end = " ")
    if s[eachCharacter]==" ":
        numberspaces + = 1
        if s[eachCharacter].lower() == 'i'
         i +=1
# Out:
#   File "<ipython-input-1-5d3d18fe24bf>", line 5
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
print("\n")
print("there are " + str (i) + "i's in the string")
print("Ther are " + str(numberSpace) + "spaces.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0e53c6737fc4> in <module>()
#       1 print("\n")
# ----> 2 print("there are " + str (i) + "i's in the string")
#       3 print("Ther are " + str(numberSpace) + "spaces.")
#
# NameError: name 'i' is not defined

# %%
while True:
    answer = input("Enter a movie you like or press 'q' to quit:")
    if answer.lower() == 'q':
        break
    else:
        print ("You entered"+" "+ answer)
            
print ("You will know exit the program")
# Out:
# Enter a movie you like or press 'q' to quit:Field of Dreams
# You entered Field of Dreams
# Enter a movie you like or press 'q' to quit:Do the Right Thing
# You entered Do the Right Thing
# Enter a movie you like or press 'q' to quit:Friday After Next
# You entered Friday After Next
# Enter a movie you like or press 'q' to quit:Cat in the Hat
# You entered Cat in the Hat
# Enter a movie you like or press 'q' to quit:Green Eggs and Ham
# You entered Green Eggs and Ham
# Enter a movie you like or press 'q' to quit:q
# You will know exit the program

# %%
'''
A string is a sequence of zero or more characters.

The len () function returns the number of characters in it's string argument.
Each character occupies a posititon in the string. The positions range from 0 to the length of the string minus 1.
A string is immutable. This means it does not change once it is created.

The subscipt operator [] can be used to access a character at a given position in a string.
'''
s = "This is my string"

i = 0

numberSpace = 0

print len (s)

print s[4]

print "Printing the subscript from 5 to 10: +s[5:10]"

for eachCharacter in range (lens(s)-1,-1,-1):
    
    print s[eachCharater],end== " "
    if s[eachCharacter]==" ":
        numberspaces += 1
        if s[eachCharacter].lower() == 'i':
            i +=1
            print("\n")
print("there are " + str (i) + "i's in the string")
print("Ther are " + str(numberSpace) + "spaces.")
# Out:
# Enter a movie you like or press 'q' to quit:hi girls
#   File "<string>", line 1
#     hi girls
#            ^
# SyntaxError: unexpected EOF while parsing

# %%
s = "This is my string"

i = 0

numberSpace = 0

print(len(s))

print(s[4])

print("Printing the subscript from 5 to 10: +s[5:10]")

for eachCharacter in range (lens(s)-1,-1,-1):
    
    print(s[eachCharater],end = " ")
    if s[eachCharacter]==" ":
        numberspaces += 1
    if s[eachCharacter].lower() == 'i':
         i +=1
    print("\n")
print("there are " + str (i) + "i's in the string")
print("Ther are " + str(numberSpace) + "spaces.")
# Out:
# 17
#
# Printing the subscript from 5 to 10: +s[5:10]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-93609065213e> in <module>()
#      11 print("Printing the subscript from 5 to 10: +s[5:10]")
#      12
# ---> 13 for eachCharacter in range (lens(s)-1,-1,-1):
#      14
#      15     print(s[eachCharater],end = " ")
#
# NameError: name 'lens' is not defined
